# %%
import pandas as pd

# Simulated audit data
audit_data = {
    "index.html": {"main_css": "✅ assets/main.css", "local_styles_removed": "✅"},
    "html/mission.html": {"main_css": "✅ ../assets/main.css", "local_styles_removed": "✅"},
    "html/models.html": {"main_css": "✅ ../assets/main.css", "local_styles_removed": "✅"},
    "html/contact.html": {"main_css": "✅ ../assets/main.css", "local_styles_removed": "✅"},
    "html/collaborators.html": {"main_css": "✅ ../assets/main.css", "local_styles_removed": "✅"},
    "html/privacy.html": {"main_css": "✅ ../assets/main.css", "local_styles_removed": "✅"},
    "html/landing.html": {"main_css": "✅ ../assets/main.css", "local_styles_removed": "✅"}
}

df = pd.DataFrame.from_dict(audit_data, orient='index')
df.index.name = "HTML File"
df
# Out:
#                                      main_css local_styles_removed
# HTML File
# index.html                  ✅ assets/main.css                    ✅
# html/mission.html        ✅ ../assets/main.css                    ✅
# html/models.html         ✅ ../assets/main.css                    ✅
# html/contact.html        ✅ ../assets/main.css                    ✅
# html/collaborators.html  ✅ ../assets/main.css                    ✅
# html/privacy.html        ✅ ../assets/main.css                    ✅
# html/landing.html        ✅ ../assets/main.css                    ✅
